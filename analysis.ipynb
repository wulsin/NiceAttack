# %% [markdown]
# # Reactions to terror:  #Nice hashtag Twitter analysis

# %% [markdown]
# On the evening of July 14, 2016, after Bastille Day fireworks in Nice, France, a truck attack killed at least 84 people.  Like many others, I was stunned by this atrocious act of terror on a holiday commemorating liberty, equality, and fraternity.  I wondered whether we can learn anything about how this happened and how such further acts of terrorism could be prevented.

# %%
import os
import sys
import matplotlib.pyplot as plt

% matplotlib inline  

plt.rcParams['figure.figsize'] = (15, 10)

# %%
import pandas as pd
import json

# %%
timestamps = pd.read_csv('timestamps.txt')

# %%
timestamps[:5]
# Out:
#                              Date
# 0  Fri Jul 15 19:20:00 +0000 2016
# 1  Fri Jul 15 19:20:00 +0000 2016
# 2  Fri Jul 15 19:20:00 +0000 2016
# 3  Fri Jul 15 19:20:00 +0000 2016
# 4  Fri Jul 15 19:20:00 +0000 2016

# %%
# a list of "1" to count the hashtags
ones = [1]*len(timestamps)
# the index of the series
idx = pd.DatetimeIndex(timestamps['Date'])
# the actual series (at series of 1s for the moment)
series = pd.Series(ones, index=idx)
# Resampling / bucketing
per_minute = series.resample('1Min', how='sum').fillna(0)
# Out:
# /Users/hwwulsin/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:8: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...).sum()

# %%
len(timestamps)
# Out:
# 262847

# %%
ones[:5]
# Out:
# [1, 1, 1, 1, 1]

# %%
per_minute[:5]
# Out:
# 2016-07-15 19:19:00      2
# 2016-07-15 19:20:00    534
# 2016-07-15 19:21:00    440
# 2016-07-15 19:22:00    445
# 2016-07-15 19:23:00    480
# Freq: T, dtype: int64

# %%
import matplotlib.dates as mdates
plt.plot(per_minute)
ax = plt.axes()
plt.gcf().autofmt_xdate()
plt.title("Tweets per minute with #Nice hashtag")
xfmt = mdates.DateFormatter('%d-%m-%y %H:%M')
ax.xaxis.set_major_formatter(xfmt)
plt.show()
